# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import seaborn
import streamlit
print("✅ Wszystkie biblioteki działają!")
# Out:
# ✅ Wszystkie biblioteki działają!

# %%
print(f"Python działa, pandas {pd.__version__}")
# Out:
# Python działa, pandas 2.1.3
